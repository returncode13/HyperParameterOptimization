# %%
from sigopt.examples import  franke_function
from comet_ml import Optimizer

# %%
def fit(x,y):
    return franke_function(x,y)

# %%
config={
    "algorithm":"bayes",
    "spec":{
        'retryAssignLimit': 1,
        'objective': "maximize",
        'metric':'val'
    },
    "parameters":{
        'x':{
            "type": "float",
            "scalingType":"uniform",
            "min":0.0,
            "max":1.0
        },
        'y':{
            "type": "float",
            "scalingType":"uniform",
            "min":0.0,
            "max":1.0
        }
    },
    "name":"Franke Function Optimizer"
}

# %%
opt=Optimizer(config,api_key="ujsGqr7agNfgZXYoUJ7sNHlLF",workspace="returncode13",project_name="franke-function-opt-02")
# Out:
# COMET WARNING: Passing Experiment through Optimizer constructor is deprecated; pass them to Optimizer.get_experiments or Optimizer.next
# COMET INFO: COMET_OPTIMIZER_ID=8ea843080d644a6aa6f622cf50dfaafe
# COMET INFO: Using optimizer config: {'algorithm': 'bayes', 'configSpaceSize': 'infinite', 'endTime': None, 'id': '8ea843080d644a6aa6f622cf50dfaafe', 'lastUpdateTime': None, 'maxCombo': 0, 'name': 'Franke Function Optimizer', 'parameters': {'x': {'max': 1.0, 'min': 0.0, 'scalingType': 'uniform', 'type': 'float'}, 'y': {'max': 1.0, 'min': 0.0, 'scalingType': 'uniform', 'type': 'float'}}, 'predictor': None, 'spec': {'gridSize': 10, 'maxCombo': 0, 'metric': 'val', 'minSampleSize': 100, 'objective': 'maximize', 'retryAssignLimit': 1, 'retryLimit': 20, 'seed': 1257202848}, 'startTime': 20476171058, 'state': {'sequence_i': 0, 'sequence_pid': None, 'sequence_retry': 0}, 'status': 'running', 'suggestion_count': 0, 'trials': 1, 'version': '1.0.24'}

# %%
for experiment in opt.get_experiments():
    val=fit(experiment.get_parameter('x'),experiment.get_parameter('y'))
    experiment.log_metric("val",val)
    #print(experiment.get_parameter('x'),experiment.get_parameter('y'))
# Out:
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/returncode13/franke-function-opt-02/b18dee40e2054b7dbec55b8110c2d404
#
# COMET INFO: ----------------------------
# COMET INFO: Comet.ml Experiment Summary:
# COMET INFO:   Data:
# COMET INFO:     url: https://www.comet.ml/returncode13/franke-function-opt-02/b18dee40e2054b7dbec55b8110c2d404
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     sys.gpu.0.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.0.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.0.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.0.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     sys.gpu.1.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.1.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.1.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.1.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     val                      : (0.30047476270464013, 0.30047476270464013)
# COMET INFO:   Other [count]:
# COMET INFO:     optimizer_count       : 1
# COMET INFO:     optimizer_id          : 8ea843080d644a6aa6f622cf50dfaafe
# COMET INFO:     optimizer_metric      : val
# COMET INFO:     optimizer_metric_value: 0.30047476270464013
# COMET INFO:     optimizer_objective   : maximize
# COMET INFO:     optimizer_parameters  : {"x": 0.08039181684603336, "y": 0.8387014704086027}
# COMET INFO:     optimizer_pid         : 77102c65c64c7b483c41d7c960941d7869e79461
# COMET INFO:     optimizer_process     : 9888
# COMET INFO:     optimizer_trial       : 1
# COMET INFO:     optimizer_version     : 1.0.24
# COMET INFO:   Uploads:
# COMET INFO:     git-patch: 1
# COMET INFO: ----------------------------
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/returncode13/franke-function-opt-02/9d29edc1fb7a4718a3037de509ae3974
#
# COMET INFO: ----------------------------
# COMET INFO: Comet.ml Experiment Summary:
# COMET INFO:   Data:
# COMET INFO:     url: https://www.comet.ml/returncode13/franke-function-opt-02/9d29edc1fb7a4718a3037de509ae3974
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     sys.gpu.0.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.0.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.0.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.0.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     sys.gpu.1.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.1.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.1.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.1.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     val                      : (0.30047476270464013, 0.30047476270464013)
# COMET INFO:   Other [count]:
# COMET INFO:     optimizer_count       : 2
# COMET INFO:     optimizer_id          : 8ea843080d644a6aa6f622cf50dfaafe
# COMET INFO:     optimizer_metric      : val
# COMET INFO:     optimizer_metric_value: 0.30047476270464013
# COMET INFO:     optimizer_objective   : maximize
# COMET INFO:     optimizer_parameters  : {"x": 0.08039181684603336, "y": 0.8387014704086027}
# COMET INFO:     optimizer_pid         : 77102c65c64c7b483c41d7c960941d7869e79461
# COMET INFO:     optimizer_process     : 9888
# COMET INFO:     optimizer_trial       : 1
# COMET INFO:     optimizer_version     : 1.0.24
# COMET INFO:   Uploads:
# COMET INFO:     git-patch: 1
# COMET INFO: ----------------------------
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/returncode13/franke-function-opt-02/c704de59da1242de98cd0eb0719e184f
#
# COMET INFO: ----------------------------
# COMET INFO: Comet.ml Experiment Summary:
# COMET INFO:   Data:
# COMET INFO:     url: https://www.comet.ml/returncode13/franke-function-opt-02/c704de59da1242de98cd0eb0719e184f
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     sys.gpu.0.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.0.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.0.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.0.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     sys.gpu.1.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.1.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.1.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.1.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     val                      : (0.3151438295939151, 0.3151438295939151)
# COMET INFO:   Other [count]:
# COMET INFO:     optimizer_count       : 3
# COMET INFO:     optimizer_id          : 8ea843080d644a6aa6f622cf50dfaafe
# COMET INFO:     optimizer_metric      : val
# COMET INFO:     optimizer_metric_value: 0.3151438295939151
# COMET INFO:     optimizer_objective   : maximize
# COMET INFO:     optimizer_parameters  : {"x": 0.013606638820000905, "y": 0.8244104616800995}
# COMET INFO:     optimizer_pid         : 63f26dcf0098643bdad6b840068c470c758bdecb
# COMET INFO:     optimizer_process     : 9888
# COMET INFO:     optimizer_trial       : 1
# COMET INFO:     optimizer_version     : 1.0.24
# COMET INFO:   Uploads:
# COMET INFO:     git-patch: 1
# COMET INFO: ----------------------------
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/returncode13/franke-function-opt-02/3cfbfb8291c84ea79c79e7cdf6c82f9c
#
# COMET INFO: ----------------------------
# COMET INFO: Comet.ml Experiment Summary:
# COMET INFO:   Data:
# COMET INFO:     url: https://www.comet.ml/returncode13/franke-function-opt-02/3cfbfb8291c84ea79c79e7cdf6c82f9c
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     sys.gpu.0.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.0.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.0.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.0.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     sys.gpu.1.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.1.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.1.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.1.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     val                      : (0.3151438295939151, 0.3151438295939151)
# COMET INFO:   Other [count]:
# COMET INFO:     optimizer_count       : 1
# COMET INFO:     optimizer_id          : 8ea843080d644a6aa6f622cf50dfaafe
# COMET INFO:     optimizer_metric      : val
# COMET INFO:     optimizer_metric_value: 0.3151438295939151
# COMET INFO:     optimizer_objective   : maximize
# COMET INFO:     optimizer_parameters  : {"x": 0.013606638820000905, "y": 0.8244104616800995}
# COMET INFO:     optimizer_pid         : 63f26dcf0098643bdad6b840068c470c758bdecb
# COMET INFO:     optimizer_process     : 9888
# COMET INFO:     optimizer_trial       : 1
# COMET INFO:     optimizer_version     : 1.0.24
# COMET INFO:   Uploads:
# COMET INFO:     git-patch: 1
# COMET INFO: ----------------------------
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/returncode13/franke-function-opt-02/1b383e79035a48f8aae7ef7270f3db45
#
# COMET INFO: ----------------------------
# COMET INFO: Comet.ml Experiment Summary:
# COMET INFO:   Data:
# COMET INFO:     url: https://www.comet.ml/returncode13/franke-function-opt-02/1b383e79035a48f8aae7ef7270f3db45
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     sys.gpu.0.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.0.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.0.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.0.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     sys.gpu.1.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.1.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.1.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.1.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     val                      : (0.07603309856859108, 0.07603309856859108)
# COMET INFO:   Other [count]:
# COMET INFO:     optimizer_count       : 1
# COMET INFO:     optimizer_id          : 8ea843080d644a6aa6f622cf50dfaafe
# COMET INFO:     optimizer_metric      : val
# COMET INFO:     optimizer_metric_value: 0.07603309856859108
# COMET INFO:     optimizer_objective   : maximize
# COMET INFO:     optimizer_parameters  : {"x": 0.8726388783859503, "y": 0.776049070637789}
# COMET INFO:     optimizer_pid         : 55f6caf96c70e7b68931591c04cc29e4aab94f94
# COMET INFO:     optimizer_process     : 9888
# COMET INFO:     optimizer_trial       : 1
# COMET INFO:     optimizer_version     : 1.0.24
# COMET INFO:   Uploads:
# COMET INFO:     git-patch: 1
# COMET INFO: ----------------------------
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/returncode13/franke-function-opt-02/2eabde773da0433797e2825021722a19
#
# COMET INFO: ----------------------------
# COMET INFO: Comet.ml Experiment Summary:
# COMET INFO:   Data:
# COMET INFO:     url: https://www.comet.ml/returncode13/franke-function-opt-02/2eabde773da0433797e2825021722a19
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     sys.gpu.0.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.0.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.0.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.0.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     sys.gpu.1.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.1.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.1.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.1.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     val                      : (0.07603309856859108, 0.07603309856859108)
# COMET INFO:   Other [count]:
# COMET INFO:     optimizer_count       : 2
# COMET INFO:     optimizer_id          : 8ea843080d644a6aa6f622cf50dfaafe
# COMET INFO:     optimizer_metric      : val
# COMET INFO:     optimizer_metric_value: 0.07603309856859108
# COMET INFO:     optimizer_objective   : maximize
# COMET INFO:     optimizer_parameters  : {"x": 0.8726388783859503, "y": 0.776049070637789}
# COMET INFO:     optimizer_pid         : 55f6caf96c70e7b68931591c04cc29e4aab94f94
# COMET INFO:     optimizer_process     : 9888
# COMET INFO:     optimizer_trial       : 1
# COMET INFO:     optimizer_version     : 1.0.24
# COMET INFO:   Uploads:
# COMET INFO:     git-patch: 1
# COMET INFO: ----------------------------
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/returncode13/franke-function-opt-02/e40e31fc302a46e69738c59e937cd4c9
#
# COMET INFO: ----------------------------
# COMET INFO: Comet.ml Experiment Summary:
# COMET INFO:   Data:
# COMET INFO:     url: https://www.comet.ml/returncode13/franke-function-opt-02/e40e31fc302a46e69738c59e937cd4c9
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     sys.gpu.0.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.0.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.0.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.0.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     sys.gpu.1.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.1.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.1.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.1.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     val                      : (0.7178704544192523, 0.7178704544192523)
# COMET INFO:   Other [count]:
# COMET INFO:     optimizer_count       : 2
# COMET INFO:     optimizer_id          : 8ea843080d644a6aa6f622cf50dfaafe
# COMET INFO:     optimizer_metric      : val
# COMET INFO:     optimizer_metric_value: 0.7178704544192523
# COMET INFO:     optimizer_objective   : maximize
# COMET INFO:     optimizer_parameters  : {"x": 0.3505491794565434, "y": 0.36222718984036817}
# COMET INFO:     optimizer_pid         : cd6a04f5ff1fd008f2f918ced3f4e2b34c107c51
# COMET INFO:     optimizer_process     : 9888
# COMET INFO:     optimizer_trial       : 1
# COMET INFO:     optimizer_version     : 1.0.24
# COMET INFO:   Uploads:
# COMET INFO:     git-patch: 1
# COMET INFO: ----------------------------
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/returncode13/franke-function-opt-02/b8807e2815484422972ed6543d59eb2a
#
# COMET INFO: ----------------------------
# COMET INFO: Comet.ml Experiment Summary:
# COMET INFO:   Data:
# COMET INFO:     url: https://www.comet.ml/returncode13/franke-function-opt-02/b8807e2815484422972ed6543d59eb2a
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     sys.gpu.0.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.0.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.0.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.0.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     sys.gpu.1.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.1.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.1.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.1.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     val                      : (0.7178704544192523, 0.7178704544192523)
# COMET INFO:   Other [count]:
# COMET INFO:     optimizer_count       : 2
# COMET INFO:     optimizer_id          : 8ea843080d644a6aa6f622cf50dfaafe
# COMET INFO:     optimizer_metric      : val
# COMET INFO:     optimizer_metric_value: 0.7178704544192523
# COMET INFO:     optimizer_objective   : maximize
# COMET INFO:     optimizer_parameters  : {"x": 0.3505491794565434, "y": 0.36222718984036817}
# COMET INFO:     optimizer_pid         : cd6a04f5ff1fd008f2f918ced3f4e2b34c107c51
# COMET INFO:     optimizer_process     : 9888
# COMET INFO:     optimizer_trial       : 1
# COMET INFO:     optimizer_version     : 1.0.24
# COMET INFO:   Uploads:
# COMET INFO:     git-patch: 1
# COMET INFO: ----------------------------
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/returncode13/franke-function-opt-02/97f0a35a3d24437eb5a389a17a00e951
#
# COMET INFO: ----------------------------
# COMET INFO: Comet.ml Experiment Summary:
# COMET INFO:   Data:
# COMET INFO:     url: https://www.comet.ml/returncode13/franke-function-opt-02/97f0a35a3d24437eb5a389a17a00e951
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     sys.gpu.0.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.0.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.0.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.0.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     sys.gpu.1.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.1.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.1.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.1.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     val                      : (0.2871274705278346, 0.2871274705278346)
# COMET INFO:   Other [count]:
# COMET INFO:     optimizer_count       : 2
# COMET INFO:     optimizer_id          : 8ea843080d644a6aa6f622cf50dfaafe
# COMET INFO:     optimizer_metric      : val
# COMET INFO:     optimizer_metric_value: 0.2871274705278346
# COMET INFO:     optimizer_objective   : maximize
# COMET INFO:     optimizer_parameters  : {"x": 0.09745121926846978, "y": 0.8761712104431131}
# COMET INFO:     optimizer_pid         : 2e00cb2c2f1d13694d6685ce93aa40a8788e5ff1
# COMET INFO:     optimizer_process     : 9888
# COMET INFO:     optimizer_trial       : 1
# COMET INFO:     optimizer_version     : 1.0.24
# COMET INFO:   Uploads:
# COMET INFO:     git-patch: 1
# COMET INFO: ----------------------------
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/returncode13/franke-function-opt-02/71ec071c3a984ba5a1a75fd75af4ba1e
#
# COMET INFO: ----------------------------
# COMET INFO: Comet.ml Experiment Summary:
# COMET INFO:   Data:
# COMET INFO:     url: https://www.comet.ml/returncode13/franke-function-opt-02/71ec071c3a984ba5a1a75fd75af4ba1e
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     sys.gpu.0.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.0.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.0.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.0.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     sys.gpu.1.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.1.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.1.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.1.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     val                      : (0.2871274705278346, 0.2871274705278346)
# COMET INFO:   Other [count]:
# COMET INFO:     optimizer_count       : 3
# COMET INFO:     optimizer_id          : 8ea843080d644a6aa6f622cf50dfaafe
# COMET INFO:     optimizer_metric      : val
# COMET INFO:     optimizer_metric_value: 0.2871274705278346
# COMET INFO:     optimizer_objective   : maximize
# COMET INFO:     optimizer_parameters  : {"x": 0.09745121926846978, "y": 0.8761712104431131}
# COMET INFO:     optimizer_pid         : 2e00cb2c2f1d13694d6685ce93aa40a8788e5ff1
# COMET INFO:     optimizer_process     : 9888
# COMET INFO:     optimizer_trial       : 1
# COMET INFO:     optimizer_version     : 1.0.24
# COMET INFO:   Uploads:
# COMET INFO:     git-patch: 1
# COMET INFO: ----------------------------
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/returncode13/franke-function-opt-02/87e57bc296e14fa8bc9b5908e19f29c4
#
# COMET INFO: ----------------------------
# COMET INFO: Comet.ml Experiment Summary:
# COMET INFO:   Data:
# COMET INFO:     url: https://www.comet.ml/returncode13/franke-function-opt-02/87e57bc296e14fa8bc9b5908e19f29c4
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     sys.gpu.0.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.0.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.0.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.0.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     sys.gpu.1.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.1.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.1.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.1.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     val                      : (0.9450713476130723, 0.9450713476130723)
# COMET INFO:   Other [count]:
# COMET INFO:     optimizer_count       : 3
# COMET INFO:     optimizer_id          : 8ea843080d644a6aa6f622cf50dfaafe
# COMET INFO:     optimizer_metric      : val
# COMET INFO:     optimizer_metric_value: 0.9450713476130723
# COMET INFO:     optimizer_objective   : maximize
# COMET INFO:     optimizer_parameters  : {"x": 0.26655763708650126, "y": 0.06583973677587796}
# COMET INFO:     optimizer_pid         : 5602ee886262e63e15dda11e1a77607e84e174a2
# COMET INFO:     optimizer_process     : 9888
# COMET INFO:     optimizer_trial       : 1
# COMET INFO:     optimizer_version     : 1.0.24
# COMET INFO:   Uploads:
# COMET INFO:     git-patch: 1
# COMET INFO: ----------------------------
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/returncode13/franke-function-opt-02/090b3fe771ef4cc59af6ac8d5630221e
#
# COMET INFO: ----------------------------
# COMET INFO: Comet.ml Experiment Summary:
# COMET INFO:   Data:
# COMET INFO:     url: https://www.comet.ml/returncode13/franke-function-opt-02/090b3fe771ef4cc59af6ac8d5630221e
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     sys.gpu.0.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.0.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.0.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.0.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     sys.gpu.1.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.1.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.1.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.1.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     val                      : (0.9450713476130723, 0.9450713476130723)
# COMET INFO:   Other [count]:
# COMET INFO:     optimizer_count       : 4
# COMET INFO:     optimizer_id          : 8ea843080d644a6aa6f622cf50dfaafe
# COMET INFO:     optimizer_metric      : val
# COMET INFO:     optimizer_metric_value: 0.9450713476130723
# COMET INFO:     optimizer_objective   : maximize
# COMET INFO:     optimizer_parameters  : {"x": 0.26655763708650126, "y": 0.06583973677587796}
# COMET INFO:     optimizer_pid         : 5602ee886262e63e15dda11e1a77607e84e174a2
# COMET INFO:     optimizer_process     : 9888
# COMET INFO:     optimizer_trial       : 1
# COMET INFO:     optimizer_version     : 1.0.24
# COMET INFO:   Uploads:
# COMET INFO:     git-patch: 1
# COMET INFO: ----------------------------
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/returncode13/franke-function-opt-02/a1fe1e6675ff4e4dafa203f21c57a458
#
# COMET INFO: ----------------------------
# COMET INFO: Comet.ml Experiment Summary:
# COMET INFO:   Data:
# COMET INFO:     url: https://www.comet.ml/returncode13/franke-function-opt-02/a1fe1e6675ff4e4dafa203f21c57a458
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     sys.gpu.0.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.0.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.0.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.0.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     sys.gpu.1.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.1.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.1.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.1.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     val                      : (0.3201909842253502, 0.3201909842253502)
# COMET INFO:   Other [count]:
# COMET INFO:     optimizer_count       : 3
# COMET INFO:     optimizer_id          : 8ea843080d644a6aa6f622cf50dfaafe
# COMET INFO:     optimizer_metric      : val
# COMET INFO:     optimizer_metric_value: 0.3201909842253502
# COMET INFO:     optimizer_objective   : maximize
# COMET INFO:     optimizer_parameters  : {"x": 0.042152313800952745, "y": 0.793302010265799}
# COMET INFO:     optimizer_pid         : fb408acb74a783d8215b3377cb573f73fb1d0bb5
# COMET INFO:     optimizer_process     : 9888
# COMET INFO:     optimizer_trial       : 1
# COMET INFO:     optimizer_version     : 1.0.24
# COMET INFO:   Uploads:
# COMET INFO:     git-patch: 1
# COMET INFO: ----------------------------
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/returncode13/franke-function-opt-02/9e47517713e64aac8a7516558c49abd2
#
# COMET INFO: ----------------------------
# COMET INFO: Comet.ml Experiment Summary:
# COMET INFO:   Data:
# COMET INFO:     url: https://www.comet.ml/returncode13/franke-function-opt-02/9e47517713e64aac8a7516558c49abd2
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     sys.gpu.0.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.0.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.0.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.0.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     sys.gpu.1.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.1.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.1.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.1.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     val                      : (0.3201909842253502, 0.3201909842253502)
# COMET INFO:   Other [count]:
# COMET INFO:     optimizer_count       : 3
# COMET INFO:     optimizer_id          : 8ea843080d644a6aa6f622cf50dfaafe
# COMET INFO:     optimizer_metric      : val
# COMET INFO:     optimizer_metric_value: 0.3201909842253502
# COMET INFO:     optimizer_objective   : maximize
# COMET INFO:     optimizer_parameters  : {"x": 0.042152313800952745, "y": 0.793302010265799}
# COMET INFO:     optimizer_pid         : fb408acb74a783d8215b3377cb573f73fb1d0bb5
# COMET INFO:     optimizer_process     : 9888
# COMET INFO:     optimizer_trial       : 1
# COMET INFO:     optimizer_version     : 1.0.24
# COMET INFO:   Uploads:
# COMET INFO:     git-patch: 1
# COMET INFO: ----------------------------
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/returncode13/franke-function-opt-02/5016030749b34b21b5b91017dba13d82
#
# COMET INFO: ----------------------------
# COMET INFO: Comet.ml Experiment Summary:
# COMET INFO:   Data:
# COMET INFO:     url: https://www.comet.ml/returncode13/franke-function-opt-02/5016030749b34b21b5b91017dba13d82
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     sys.gpu.0.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.0.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.0.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.0.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     sys.gpu.1.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.1.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.1.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.1.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     val                      : (0.5254830362913042, 0.5254830362913042)
# COMET INFO:   Other [count]:
# COMET INFO:     optimizer_count       : 2
# COMET INFO:     optimizer_id          : 8ea843080d644a6aa6f622cf50dfaafe
# COMET INFO:     optimizer_metric      : val
# COMET INFO:     optimizer_metric_value: 0.5254830362913042
# COMET INFO:     optimizer_objective   : maximize
# COMET INFO:     optimizer_parameters  : {"x": 0.7353708313580075, "y": 0.20736111194043583}
# COMET INFO:     optimizer_pid         : 5e325ea0ac203fd726f0a3179e661fc47cb77f55
# COMET INFO:     optimizer_process     : 9888
# COMET INFO:     optimizer_trial       : 1
# COMET INFO:     optimizer_version     : 1.0.24
# COMET INFO:   Uploads:
# COMET INFO:     git-patch: 1
# COMET INFO: ----------------------------
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/returncode13/franke-function-opt-02/b5369789963b4c70bfc9b338f6fd0ffa
#
# COMET INFO: ----------------------------
# COMET INFO: Comet.ml Experiment Summary:
# COMET INFO:   Data:
# COMET INFO:     url: https://www.comet.ml/returncode13/franke-function-opt-02/b5369789963b4c70bfc9b338f6fd0ffa
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     sys.gpu.0.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.0.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.0.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.0.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     sys.gpu.1.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.1.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.1.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.1.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     val                      : (0.5254830362913042, 0.5254830362913042)
# COMET INFO:   Other [count]:
# COMET INFO:     optimizer_count       : 3
# COMET INFO:     optimizer_id          : 8ea843080d644a6aa6f622cf50dfaafe
# COMET INFO:     optimizer_metric      : val
# COMET INFO:     optimizer_metric_value: 0.5254830362913042
# COMET INFO:     optimizer_objective   : maximize
# COMET INFO:     optimizer_parameters  : {"x": 0.7353708313580075, "y": 0.20736111194043583}
# COMET INFO:     optimizer_pid         : 5e325ea0ac203fd726f0a3179e661fc47cb77f55
# COMET INFO:     optimizer_process     : 9888
# COMET INFO:     optimizer_trial       : 1
# COMET INFO:     optimizer_version     : 1.0.24
# COMET INFO:   Uploads:
# COMET INFO:     git-patch: 1
# COMET INFO: ----------------------------
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/returncode13/franke-function-opt-02/0eedbee915984d2a9efd288b5ad08ce8
#
# COMET INFO: ----------------------------
# COMET INFO: Comet.ml Experiment Summary:
# COMET INFO:   Data:
# COMET INFO:     url: https://www.comet.ml/returncode13/franke-function-opt-02/0eedbee915984d2a9efd288b5ad08ce8
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     sys.gpu.0.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.0.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.0.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.0.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     sys.gpu.1.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.1.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.1.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.1.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     val                      : (0.8341194846598348, 0.8341194846598348)
# COMET INFO:   Other [count]:
# COMET INFO:     optimizer_count       : 3
# COMET INFO:     optimizer_id          : 8ea843080d644a6aa6f622cf50dfaafe
# COMET INFO:     optimizer_metric      : val
# COMET INFO:     optimizer_metric_value: 0.8341194846598348
# COMET INFO:     optimizer_objective   : maximize
# COMET INFO:     optimizer_parameters  : {"x": 0.005788205198492213, "y": 0.22129695106785063}
# COMET INFO:     optimizer_pid         : e2b0e48349ff93047f02fd023329c16a12aa4526
# COMET INFO:     optimizer_process     : 9888
# COMET INFO:     optimizer_trial       : 1
# COMET INFO:     optimizer_version     : 1.0.24
# COMET INFO:   Uploads:
# COMET INFO:     git-patch: 1
# COMET INFO: ----------------------------
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/returncode13/franke-function-opt-02/84bbb85605824c788ecbfc8068a5c850
#
# COMET INFO: ----------------------------
# COMET INFO: Comet.ml Experiment Summary:
# COMET INFO:   Data:
# COMET INFO:     url: https://www.comet.ml/returncode13/franke-function-opt-02/84bbb85605824c788ecbfc8068a5c850
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     sys.gpu.0.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.0.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.0.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.0.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     sys.gpu.1.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.1.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.1.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.1.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     val                      : (0.8341194846598348, 0.8341194846598348)
# COMET INFO:   Other [count]:
# COMET INFO:     optimizer_count       : 5
# COMET INFO:     optimizer_id          : 8ea843080d644a6aa6f622cf50dfaafe
# COMET INFO:     optimizer_metric      : val
# COMET INFO:     optimizer_metric_value: 0.8341194846598348
# COMET INFO:     optimizer_objective   : maximize
# COMET INFO:     optimizer_parameters  : {"x": 0.005788205198492213, "y": 0.22129695106785063}
# COMET INFO:     optimizer_pid         : e2b0e48349ff93047f02fd023329c16a12aa4526
# COMET INFO:     optimizer_process     : 9888
# COMET INFO:     optimizer_trial       : 1
# COMET INFO:     optimizer_version     : 1.0.24
# COMET INFO:   Uploads:
# COMET INFO:     git-patch: 1
# COMET INFO: ----------------------------
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/returncode13/franke-function-opt-02/518bd9aebed449b0b06efb6191db69ba
#
# COMET INFO: ----------------------------
# COMET INFO: Comet.ml Experiment Summary:
# COMET INFO:   Data:
# COMET INFO:     url: https://www.comet.ml/returncode13/franke-function-opt-02/518bd9aebed449b0b06efb6191db69ba
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     sys.gpu.0.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.0.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.0.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.0.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     sys.gpu.1.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.1.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.1.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.1.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     val                      : (0.1007132386283979, 0.1007132386283979)
# COMET INFO:   Other [count]:
# COMET INFO:     optimizer_count       : 4
# COMET INFO:     optimizer_id          : 8ea843080d644a6aa6f622cf50dfaafe
# COMET INFO:     optimizer_metric      : val
# COMET INFO:     optimizer_metric_value: 0.1007132386283979
# COMET INFO:     optimizer_objective   : maximize
# COMET INFO:     optimizer_parameters  : {"x": 0.7080321667339674, "y": 0.8933858441744744}
# COMET INFO:     optimizer_pid         : 7fcf2f9586eeef41bfc57e46b305e2eee6d0be71
# COMET INFO:     optimizer_process     : 9888
# COMET INFO:     optimizer_trial       : 1
# COMET INFO:     optimizer_version     : 1.0.24
# COMET INFO:   Uploads:
# COMET INFO:     git-patch: 1
# COMET INFO: ----------------------------
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/returncode13/franke-function-opt-02/bee2649072f4418ea7db80534d21b9a8
#
# COMET INFO: ----------------------------
# COMET INFO: Comet.ml Experiment Summary:
# COMET INFO:   Data:
# COMET INFO:     url: https://www.comet.ml/returncode13/franke-function-opt-02/bee2649072f4418ea7db80534d21b9a8
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     sys.gpu.0.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.0.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.0.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.0.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     sys.gpu.1.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.1.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.1.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.1.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     val                      : (0.1007132386283979, 0.1007132386283979)
# COMET INFO:   Other [count]:
# COMET INFO:     optimizer_count       : 4
# COMET INFO:     optimizer_id          : 8ea843080d644a6aa6f622cf50dfaafe
# COMET INFO:     optimizer_metric      : val
# COMET INFO:     optimizer_metric_value: 0.1007132386283979
# COMET INFO:     optimizer_objective   : maximize
# COMET INFO:     optimizer_parameters  : {"x": 0.7080321667339674, "y": 0.8933858441744744}
# COMET INFO:     optimizer_pid         : 7fcf2f9586eeef41bfc57e46b305e2eee6d0be71
# COMET INFO:     optimizer_process     : 9888
# COMET INFO:     optimizer_trial       : 1
# COMET INFO:     optimizer_version     : 1.0.24
# COMET INFO:   Uploads:
# COMET INFO:     git-patch: 1
# COMET INFO: ----------------------------
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/returncode13/franke-function-opt-02/04bb02b019d4412dbfa1ef9bba2bbfbc
#
# COMET INFO: ----------------------------
# COMET INFO: Comet.ml Experiment Summary:
# COMET INFO:   Data:
# COMET INFO:     url: https://www.comet.ml/returncode13/franke-function-opt-02/04bb02b019d4412dbfa1ef9bba2bbfbc
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     sys.gpu.0.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.0.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.0.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.0.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     sys.gpu.1.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.1.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.1.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.1.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     val                      : (0.25731276836232636, 0.25731276836232636)
# COMET INFO:   Other [count]:
# COMET INFO:     optimizer_count       : 4
# COMET INFO:     optimizer_id          : 8ea843080d644a6aa6f622cf50dfaafe
# COMET INFO:     optimizer_metric      : val
# COMET INFO:     optimizer_metric_value: 0.25731276836232636
# COMET INFO:     optimizer_objective   : maximize
# COMET INFO:     optimizer_parameters  : {"x": 0.2100590358942631, "y": 0.8845272984173586}
# COMET INFO:     optimizer_pid         : 4e71247f75a29b10c18fa79a9d0db0f0a04d5cb6
# COMET INFO:     optimizer_process     : 9888
# COMET INFO:     optimizer_trial       : 1
# COMET INFO:     optimizer_version     : 1.0.24
# COMET INFO:   Uploads:
# COMET INFO:     git-patch: 1
# COMET INFO: ----------------------------
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/returncode13/franke-function-opt-02/eb85cb67c47d4500bfd423ba9f187c7d
#
# COMET INFO: ----------------------------
# COMET INFO: Comet.ml Experiment Summary:
# COMET INFO:   Data:
# COMET INFO:     url: https://www.comet.ml/returncode13/franke-function-opt-02/eb85cb67c47d4500bfd423ba9f187c7d
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     sys.gpu.0.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.0.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.0.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.0.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     sys.gpu.1.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.1.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.1.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.1.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     val                      : (0.25731276836232636, 0.25731276836232636)
# COMET INFO:   Other [count]:
# COMET INFO:     optimizer_count       : 3
# COMET INFO:     optimizer_id          : 8ea843080d644a6aa6f622cf50dfaafe
# COMET INFO:     optimizer_metric      : val
# COMET INFO:     optimizer_metric_value: 0.25731276836232636
# COMET INFO:     optimizer_objective   : maximize
# COMET INFO:     optimizer_parameters  : {"x": 0.2100590358942631, "y": 0.8845272984173586}
# COMET INFO:     optimizer_pid         : 4e71247f75a29b10c18fa79a9d0db0f0a04d5cb6
# COMET INFO:     optimizer_process     : 9888
# COMET INFO:     optimizer_trial       : 1
# COMET INFO:     optimizer_version     : 1.0.24
# COMET INFO:   Uploads:
# COMET INFO:     git-patch: 1
# COMET INFO: ----------------------------
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/returncode13/franke-function-opt-02/f41f802b6d6541ef8cf1b8dd4af5c4ee
#
# COMET INFO: ----------------------------
# COMET INFO: Comet.ml Experiment Summary:
# COMET INFO:   Data:
# COMET INFO:     url: https://www.comet.ml/returncode13/franke-function-opt-02/f41f802b6d6541ef8cf1b8dd4af5c4ee
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     sys.gpu.0.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.0.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.0.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.0.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     sys.gpu.1.free_memory    : (12002066432.0, 12002066432.0)
# COMET INFO:     sys.gpu.1.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.1.total_memory   : (12004491264.0, 12004491264.0)
# COMET INFO:     sys.gpu.1.used_memory    : (2424832.0, 2424832.0)
# COMET INFO:     val                      : (0.41299338759693943, 0.41299338759693943)
# COMET INFO:   Other [count]:
# COMET INFO:     optimizer_count       : 5
# COMET INFO:     optimizer_id          : 8ea843080d644a6aa6f622cf50dfaafe
# COMET INFO:     optimizer_metric      : val
# COMET INFO:     optimizer_metric_value: 0.41299338759693943
# COMET INFO:     optimizer_objective   : maximize
# COMET INFO:     optimizer_parameters  : {"x": 0.8218434795168323, "y": 0.16669578063140567}
# COMET INFO:     optimizer_pid         : 36f7036ed119207f231e975715cdb7c3e1b6e78a
# COMET INFO:     optimizer_process     : 9888
# COMET INFO:     optimizer_trial       : 1
# COMET INFO:     optimizer_version     : 1.0.24
# COMET INFO:   Uploads:
# COMET INFO:     git-patch: 1
# COMET INFO: ----------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-24698190c117> in <module>
# ----> 1 for experiment in opt.get_experiments():
#       2     val=fit(experiment.get_parameter('x'),experiment.get_parameter('y'))
#       3     experiment.log_metric("val",val)
#       4     #print(experiment.get_parameter('x'),experiment.get_parameter('y'))
#
# C:\Anaconda\envs\py36gpu\lib\site-packages\comet_ml\optimizer.py in get_experiments(self, **kwargs)
#     193         """
#     194         while True:
# --> 195             experiment = self.next(**kwargs)
#     196             if experiment is not None:
#     197                 yield experiment
#
# C:\Anaconda\envs\py36gpu\lib\site-packages\comet_ml\optimizer.py in next(self, **kwargs)
#     229                 data["trial"],
#     230                 data["count"],
# --> 231                 experiment_kwargs=kwargs,
#     232             )
#     233         else:
#
# C:\Anaconda\envs\py36gpu\lib\site-packages\comet_ml\optimizer.py in _create_experiment(self, parameters, pid, trial, count, experiment_kwargs)
#     551
#     552         if self.experiment_class == "Experiment":
# --> 553             exp = Experiment(**experiment_kwargs)
#     554         elif self.experiment_class == "OfflineExperiment":
#     555             exp = OfflineExperiment(**experiment_kwargs)
#
# C:\Anaconda\envs\py36gpu\lib\site-packages\comet_ml\__init__.py in __init__(self, api_key, project_name, workspace, log_code, log_graph, auto_param_logging, auto_metric_logging, parse_args, auto_output_logging, log_env_details, log_git_metadata, log_git_patch, disabled, log_env_gpu, log_env_host, display_summary, log_env_cpu)
#     212
#     213         if disabled is not True:
# --> 214             self._start()
#     215
#     216             if self.alive is True:
#
# C:\Anaconda\envs\py36gpu\lib\site-packages\comet_ml\experiment.py in _start(self)
#     563     def _start(self):
#     564         try:
# --> 565             self.alive = self._setup_streamer()
#     566
#     567             if not self.alive:
#
# C:\Anaconda\envs\py36gpu\lib\site-packages\comet_ml\__init__.py in _setup_streamer(self)
#     240
#     241         try:
# --> 242             results = self._authenticate()
#     243             if results:
#     244                 ws_server_from_backend, initial_offset = results
#
# C:\Anaconda\envs\py36gpu\lib\site-packages\comet_ml\__init__.py in _authenticate(self)
#     274         """
#     275         # Get an id for this run
# --> 276         run_id_results = self.connection.get_run_id(self.project_name, self.workspace)
#     277
#     278         (
#
# C:\Anaconda\envs\py36gpu\lib\site-packages\comet_ml\connection.py in get_run_id(self, project_name, workspace, offline)
#     484         LOGGER.debug("Get run id URL: %s", endpoint_url)
#     485         r = self._low_level_http_client.post(
# --> 486             url=endpoint_url, payload=payload, retry=True
#     487         )
#     488
#
# C:\Anaconda\envs\py36gpu\lib\site-packages\comet_ml\connection.py in post(self, url, payload, headers, retry, timeout, params, files, check_status_code)
#     352                 timeout=timeout,
#     353                 files=files,
# --> 354                 params=params,
#     355             )
#     356         else:
#
# C:\Anaconda\envs\py36gpu\lib\site-packages\requests\sessions.py in post(self, url, data, json, **kwargs)
#     576         """
#     577
# --> 578         return self.request('POST', url, data=data, json=json, **kwargs)
#     579
#     580     def put(self, url, data=None, **kwargs):
#
# C:\Anaconda\envs\py36gpu\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# C:\Anaconda\envs\py36gpu\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# C:\Anaconda\envs\py36gpu\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# C:\Anaconda\envs\py36gpu\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     670                 body=body,
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#     674
#
# C:\Anaconda\envs\py36gpu\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                     # Python 3 (including for exceptions like SystemExit).
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     423             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# C:\Anaconda\envs\py36gpu\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# C:\Anaconda\envs\py36gpu\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     414                 # Python 3
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#     418                     # Remove the TypeError from the exception chain in
#
# C:\Anaconda\envs\py36gpu\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# C:\Anaconda\envs\py36gpu\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# C:\Anaconda\envs\py36gpu\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# C:\Anaconda\envs\py36gpu\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# C:\Anaconda\envs\py36gpu\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     323                 raise
#     324         except OpenSSL.SSL.WantReadError:
# --> 325             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     326                 raise timeout("The read operation timed out")
#     327             else:
#
# C:\Anaconda\envs\py36gpu\lib\site-packages\urllib3\util\wait.py in wait_for_read(sock, timeout)
#     144     Returns True if the socket is readable, or False if the timeout expired.
#     145     """
# --> 146     return wait_for_socket(sock, read=True, timeout=timeout)
#     147
#     148
#
# C:\Anaconda\envs\py36gpu\lib\site-packages\urllib3\util\wait.py in select_wait_for_socket(sock, read, write, timeout)
#      84     # thing.)
#      85     fn = partial(select.select, rcheck, wcheck, wcheck)
# ---> 86     rready, wready, xready = _retry_on_intr(fn, timeout)
#      87     return bool(rready or wready or xready)
#      88
#
# C:\Anaconda\envs\py36gpu\lib\site-packages\urllib3\util\wait.py in _retry_on_intr(fn, timeout)
#      41     # Modern Python, that retries syscalls by default
#      42     def _retry_on_intr(fn, timeout):
# ---> 43         return fn(timeout)
#      44
#      45
#
# KeyboardInterrupt:
